# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import pickle
import random

# %%
image=np.array(Image.open(r'cattowo.jpg'))#.resize((1500,1000)))
plt.imshow(image[:,:,0])
plt.title("Cattowow")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
image[:,:,0]
# Out:
# array([[182, 182, 182, ..., 159, 159, 159],
#        [182, 182, 182, ..., 160, 160, 160],
#        [183, 183, 183, ..., 160, 160, 160],
#        ...,
#        [102,  99, 100, ..., 102, 101, 100],
#        [103, 100, 101, ..., 103, 101, 100],
#        [103, 101, 101, ..., 104, 102, 100]], dtype=uint8)

# %%
image[:,:,1]
# Out:
# array([[192, 192, 192, ..., 187, 187, 187],
#        [192, 192, 192, ..., 188, 188, 188],
#        [193, 193, 193, ..., 188, 188, 188],
#        ...,
#        [144, 141, 140, ..., 142, 140, 139],
#        [146, 142, 141, ..., 143, 140, 139],
#        [146, 144, 142, ..., 144, 140, 139]], dtype=uint8)

# %%
image[:,:,2]
# Out:
# array([[93, 93, 93, ..., 64, 64, 64],
#        [93, 93, 93, ..., 65, 65, 65],
#        [94, 94, 94, ..., 65, 65, 65],
#        ...,
#        [18, 15, 17, ..., 43, 34, 32],
#        [15, 14, 16, ..., 44, 34, 32],
#        [13, 13, 14, ..., 45, 37, 32]], dtype=uint8)
